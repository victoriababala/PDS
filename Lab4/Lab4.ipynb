# %%
import pandas as pd

# %%
#1
df = pd.read_csv('Countries.csv', sep=",")

# %%
df.head()
# Out:
#   Country Name Country Code  Year  Agriculture (% GDP)  \
# 0  Afghanistan          AFG  2000            27.501127
# 1  Afghanistan          AFG  2001            27.501127
# 2  Afghanistan          AFG  2002            38.627892
# 3  Afghanistan          AFG  2003            37.418855
# 4  Afghanistan          AFG  2004            29.721067
#
#    Ease of Doing Business  Education Expenditure (% GDP)  Export (% GDP)  \
# 0               40.717968                      13.670101             NaN
# 1               40.717968                      13.670101             NaN
# 2               40.717968                      13.670101             NaN
# 3               40.717968                      13.670101             NaN
# 4               40.717968                      13.670101             NaN
#
#             GDP  Health Expenditure (% GDP)  Import (% GDP)  ...  Population  \
# 0  1.415197e+10                   10.902580             NaN  ...  19542982.0
# ...

# %%
#2
df = df.drop(df[df['Year'] !=  2022].index)
df.head()
# Out:
#        Country Name Country Code  Year  Agriculture (% GDP)  \
# 22      Afghanistan          AFG  2022            27.501127
# 45          Albania          ALB  2022            18.628032
# 68          Algeria          DZA  2022            11.384084
# 91   American Samoa          ASM  2022                  NaN
# 114         Andorra          AND  2022             0.495686
#
#      Ease of Doing Business  Education Expenditure (% GDP)  Export (% GDP)  \
# 22                40.717968                      13.670101             NaN
# 45                64.763660                      11.672968       37.463435
# 68                46.736176                      15.354617       31.676914
# 91                      NaN                            NaN       76.969167
# 114                     NaN                      10.639908             NaN
#
#               GDP  Health Expenditure (% GDP)  Import (% GDP)  ...  \
# 22   1.415197e+10                   10.902580             NaN  ...
# ...

# %%
#3
new_df = df[['Country Name', 'Population', 'Continent Name', 'GDP','Education Expenditure (% GDP)','Health Expenditure (% GDP)']]
new_df.head()
# Out:
#        Country Name  Population Continent Name           GDP  \
# 22      Afghanistan  41128771.0           Asia  1.415197e+10
# 45          Albania   2775634.0         Europe  1.888210e+10
# 68          Algeria  44903225.0         Africa  1.919129e+11
# 91   American Samoa     44273.0        Oceania  6.011000e+08
# 114         Andorra     79824.0         Europe  3.352033e+09
#
#      Education Expenditure (% GDP)  Health Expenditure (% GDP)
# 22                       13.670101                   10.902580
# 45                       11.672968                    6.093392
# 68                       15.354617                    5.035450
# 91                             NaN                         NaN
# 114                      10.639908                    6.521148

# %%
#4
new_df['Country Name'].nunique()
# Out:
# 215

# %%
#5
print(new_df['Continent Name'].unique())
new_df['Continent Name'].nunique()
# Out:
# ['Asia' 'Europe' 'Africa' 'Oceania' 'North America' 'South America']
# 6

# %%
#6
new_df[new_df["Continent Name"] == 'Europe']['Country Name'].nunique()
# Out:
# 52

# %%
#7
print(new_df['Continent Name'].value_counts())
continents = new_df['Continent Name'].value_counts()
new_df.dtypes['Continent Name']
# Out:
# Continent Name
# Africa           54
# Europe           52
# Asia             51
# North America    34
# Oceania          19
# South America    12
# Name: count, dtype: int64
# dtype('O')

# %%
continents.idxmax()
# Out:
# 'Africa'

# %%
continents.argmax()
# Out:
# 0

# %%
#8
new_df['Cont.idxmax()
# Out:
# 'Africa'

# %%
#9
new_df[new_df["Education Expenditure (% GDP)"] > 25]['Country Name']
# Out:
# 2943    Marshall Islands
# 4139     Solomon Islands
# Name: Country Name, dtype: object

# %%
#10
new_df['Health Expenditure (% GDP)'].isna().sum()
# Out:
# 25

# %%
#11
new_df['Health Expenditure (% GDP)'].fillna(5)
new_df.head()
# Out:
#        Country Name  Population Continent Name           GDP  \
# 22      Afghanistan  41128771.0           Asia  1.415197e+10
# 45          Albania   2775634.0         Europe  1.888210e+10
# 68          Algeria  44903225.0         Africa  1.919129e+11
# 91   American Samoa     44273.0        Oceania  6.011000e+08
# 114         Andorra     79824.0         Europe  3.352033e+09
#
#      Education Expenditure (% GDP)  Health Expenditure (% GDP)
# 22                       13.670101                   10.902580
# 45                       11.672968                    6.093392
# 68                       15.354617                    5.035450
# 91                             NaN                         NaN
# 114                      10.639908                    6.521148

# %%
#12
new_df[new_df['Continent Name'].str.contains('America')]
# Out:
#                         Country Name   Population Continent Name  \
# 160              Antigua and Barbuda      93763.0  North America
# 183                        Argentina   46234830.0  South America
# 252                            Aruba     106445.0  North America
# 367                     Bahamas, The     409984.0  North America
# 436                         Barbados     281635.0  North America
# 505                           Belize     405272.0  North America
# 551                          Bermuda      63532.0  North America
# 597                          Bolivia   12224110.0  South America
# 666                           Brazil  215313498.0  South America
# 689           British Virgin Islands      31305.0  North America
# 873                           Canada   38929902.0  North America
# 896                   Cayman Islands      68706.0  North America
# 965                            Chile   19603733.0  South America
# ...

# %%
#13
new_df = new_df.reset_index(drop=True)

# %%
new_df.head()
# Out:
#      Country Name  Population Continent Name           GDP  \
# 0     Afghanistan  41128771.0           Asia  1.415197e+10
# 1         Albania   2775634.0         Europe  1.888210e+10
# 2         Algeria  44903225.0         Africa  1.919129e+11
# 3  American Samoa     44273.0        Oceania  6.011000e+08
# 4         Andorra     79824.0         Europe  3.352033e+09
#
#    Education Expenditure (% GDP)  Health Expenditure (% GDP)
# 0                      13.670101                   10.902580
# 1                      11.672968                    6.093392
# 2                      15.354617                    5.035450
# 3                            NaN                         NaN
# 4                      10.639908                    6.521148

# %%
#14
new_df[new_df['Country Name'] == 'Ukraine']
# Out:
#     Country Name  Population Continent Name           GDP  \
# 208      Ukraine  38000000.0         Europe  1.605027e+11
#
#      Education Expenditure (% GDP)  Health Expenditure (% GDP)
# 208                      13.718567                    6.689784

# %%
#15
new_df[new_df['Country Name'] == 'Ukraine']['GDP']
# Out:
# 208    1.605027e+11
# Name: GDP, dtype: float64

# %%
#16
# new_df[new_df['GDP'] == new_df['GDP'].min()]['Country Name']
new_df.loc[new_df['GDP'].idxmin(), 'Country Name']
# Out:
# 'Tuvalu'

# %%
#17
new_df.set_index( 'Country Name',inplace =True)
new_df.head()
# Out:
#                 Population Continent Name           GDP  \
# Country Name
# Afghanistan     41128771.0           Asia  1.415197e+10
# Albania          2775634.0         Europe  1.888210e+10
# Algeria         44903225.0         Africa  1.919129e+11
# American Samoa     44273.0        Oceania  6.011000e+08
# Andorra            79824.0         Europe  3.352033e+09
#
#                 Education Expenditure (% GDP)  Health Expenditure (% GDP)
# Country Name
# Afghanistan                         13.670101                   10.902580
# Albania                             11.672968                    6.093392
# Algeria                             15.354617                    5.035450
# American Samoa                            NaN                         NaN
# Andorra                             10.639908                    6.521148

# %%
#18
new_df.loc['Ukraine']
# Out:
# Population                                38000000.0
# Continent Name                                Europe
# GDP                              160502739236.096985
# Education Expenditure (% GDP)              13.718567
# Health Expenditure (% GDP)                  6.689784
# Name: Ukraine, dtype: object

# %%
#19
new_df.loc['Ukraine']['GDP']
# Out:
# 160502739236.097

# %%
#20
new_df['GDP'].idxmin()
# Out:
# 'Tuvalu'

# %%
#21
new_df = new_df.reset_index()
new_df.head()
# Out:
#      Country Name  Population Continent Name           GDP  \
# 0     Afghanistan  41128771.0           Asia  1.415197e+10
# 1         Albania   2775634.0         Europe  1.888210e+10
# 2         Algeria  44903225.0         Africa  1.919129e+11
# 3  American Samoa     44273.0        Oceania  6.011000e+08
# 4         Andorra     79824.0         Europe  3.352033e+09
#
#    Education Expenditure (% GDP)  Health Expenditure (% GDP)
# 0                      13.670101                   10.902580
# 1                      11.672968                    6.093392
# 2                      15.354617                    5.035450
# 3                            NaN                         NaN
# 4                      10.639908                    6.521148

# %%
#22
new_df.set_index( 'Continent Name',inplace =True)
new_df.head()
# Out:
#                   Country Name  Population           GDP  \
# Continent Name
# Asia               Afghanistan  41128771.0  1.415197e+10
# Europe                 Albania   2775634.0  1.888210e+10
# Africa                 Algeria  44903225.0  1.919129e+11
# Oceania         American Samoa     44273.0  6.011000e+08
# Europe                 Andorra     79824.0  3.352033e+09
#
#                 Education Expenditure (% GDP)  Health Expenditure (% GDP)
# Continent Name
# Asia                                13.670101                   10.902580
# Europe                              11.672968                    6.093392
# Africa                              15.354617                    5.035450
# Oceania                                   NaN                         NaN
# Europe                              10.639908                    6.521148

# %%
#23
new_df.loc['South America']
# Out:
#                  Country Name   Population           GDP  \
# Continent Name
# South America       Argentina   46234830.0  6.327703e+11
# South America         Bolivia   12224110.0  4.306889e+10
# South America          Brazil  215313498.0  1.920096e+12
# South America           Chile   19603733.0  3.010252e+11
# South America        Colombia   51874024.0  3.439394e+11
# South America         Ecuador   18001000.0  1.150495e+11
# South America          Guyana     808726.0  1.535754e+10
# South America        Paraguay    6780744.0  4.172230e+10
# South America            Peru   34049588.0  2.426315e+11
# South America        Suriname     618040.0  3.620655e+09
# South America         Uruguay    3422794.0  7.117715e+10
# South America   Venezuela, RB   28301696.0  2.452296e+11
#
#                 Education Expenditure (% GDP)  Health Expenditure (% GDP)
# Continent Name
# South America                       14.630312                    8.838312
# ...

# %%
#24
new_df[new_df['Country Name'].isin(['Ukraine'])]
# Out:
#                Country Name  Population           GDP  \
# Continent Name
# Europe              Ukraine  38000000.0  1.605027e+11
#
#                 Education Expenditure (% GDP)  Health Expenditure (% GDP)
# Continent Name
# Europe                              13.718567                    6.689784

# %%
#25
new_df[new_df['Country Name'].isin(['Ukraine'])]['GDP']
# Out:
# Continent Name
# Europe    1.605027e+11
# Name: GDP, dtype: float64

# %%
#26
new_df = new_df.reset_index()
new_df.head()
# Out:
#   Continent Name    Country Name  Population           GDP  \
# 0           Asia     Afghanistan  41128771.0  1.415197e+10
# 1         Europe         Albania   2775634.0  1.888210e+10
# 2         Africa         Algeria  44903225.0  1.919129e+11
# 3        Oceania  American Samoa     44273.0  6.011000e+08
# 4         Europe         Andorra     79824.0  3.352033e+09
#
#    Education Expenditure (% GDP)  Health Expenditure (% GDP)
# 0                      13.670101                   10.902580
# 1                      11.672968                    6.093392
# 2                      15.354617                    5.035450
# 3                            NaN                         NaN
# 4                      10.639908                    6.521148

# %%
#27
new_df.set_index( 'Country Name',inplace =True)
new_df.head()
# Out:
#                Continent Name  Population           GDP  \
# Country Name
# Afghanistan              Asia  41128771.0  1.415197e+10
# Albania                Europe   2775634.0  1.888210e+10
# Algeria                Africa  44903225.0  1.919129e+11
# American Samoa        Oceania     44273.0  6.011000e+08
# Andorra                Europe     79824.0  3.352033e+09
#
#                 Education Expenditure (% GDP)  Health Expenditure (% GDP)
# Country Name
# Afghanistan                         13.670101                   10.902580
# Albania                             11.672968                    6.093392
# Algeria                             15.354617                    5.035450
# American Samoa                            NaN                         NaN
# Andorra                             10.639908                    6.521148

# %%
#28

south_america = new_df[new_df['Continent Name'] == 'South America']

south_america.loc[south_america['Education Expenditure (% GDP)'].idxmax()]
# Out:
# Country Name                          Venezuela, RB
# Continent Name                        South America
# Population                               28301696.0
# GDP                              245229642866.11319
# Education Expenditure (% GDP)             18.579773
# Health Expenditure (% GDP)                 6.005379
# Name: 215, dtype: object

# %%
#29
new_df[new_df['Population'] > 200000000].index
# Out:
# Index(['Brazil', 'China', 'India', 'Indonesia', 'Nigeria', 'Pakistan',
#        'United States'],
#       dtype='object', name='Country Name')

# %%
#30

population_by_continent = new_df.groupby('Continent Name')['Population'].sum()

population_by_continent_df = population_by_continent.reset_index()

population_by_continent_df.loc[population_by_continent_df['Population'].idxmax()]
# Out:
# Continent Name            Asia
# Population        4830945785.0
# Name: 1, dtype: object

# %%
#31
new_df = new_df.reset_index()
new_df.head()
# Out:
#      Country Name Continent Name  Population           GDP  \
# 0     Afghanistan           Asia  41128771.0  1.415197e+10
# 1         Albania         Europe   2775634.0  1.888210e+10
# 2         Algeria         Africa  44903225.0  1.919129e+11
# 3  American Samoa        Oceania     44273.0  6.011000e+08
# 4         Andorra         Europe     79824.0  3.352033e+09
#
#    Education Expenditure (% GDP)  Health Expenditure (% GDP)
# 0                      13.670101                   10.902580
# 1                      11.672968                    6.093392
# 2                      15.354617                    5.035450
# 3                            NaN                         NaN
# 4                      10.639908                    6.521148

# %%
#32
new_df.groupby('Continent Name')['Country Name'].count()
# Out:
# Continent Name
# Africa           54
# Asia             51
# Europe           52
# North America    34
# Oceania          19
# South America    12
# Name: Country Name, dtype: int64

# %%
#33
new_df.groupby('Continent Name')['Country Name'].apply(list)
# Out:
# Continent Name
# Africa           [Algeria, Angola, Benin, Botswana, Burkina Fas...
# Asia             [Afghanistan, Armenia, Azerbaijan, Bahrain, Ba...
# Europe           [Albania, Andorra, Armenia, Austria, Azerbaija...
# North America    [Antigua and Barbuda, Aruba, Bahamas, The, Bar...
# Oceania          [American Samoa, Australia, Fiji, French Polyn...
# South America    [Argentina, Bolivia, Brazil, Chile, Colombia, ...
# Name: Country Name, dtype: object

# %%
#34
countrylist = pd.read_csv('country-list.csv', sep=",")
countrylist.head()
# Out:
#                  country              capital            type
# 0               Abkhazia              Sukhumi  countryCapital
# 1            Afghanistan                Kabul  countryCapital
# 2  Akrotiri and Dhekelia  Episkopi Cantonment  countryCapital
# 3                Albania               Tirana  countryCapital
# 4                Algeria              Algiers  countryCapital

# %%
#35
res = pd.merge(new_df, countrylist, left_on='Country Name', right_on='country',  how='inner')
res.head()
# Out:
#      Country Name Continent Name  Population           GDP  \
# 0     Afghanistan           Asia  41128771.0  1.415197e+10
# 1         Albania         Europe   2775634.0  1.888210e+10
# 2         Algeria         Africa  44903225.0  1.919129e+11
# 3  American Samoa        Oceania     44273.0  6.011000e+08
# 4         Andorra         Europe     79824.0  3.352033e+09
#
#    Education Expenditure (% GDP)  Health Expenditure (% GDP)         country  \
# 0                      13.670101                   10.902580     Afghanistan
# 1                      11.672968                    6.093392         Albania
# 2                      15.354617                    5.035450         Algeria
# 3                            NaN                         NaN  American Samoa
# 4                      10.639908                    6.521148         Andorra
#
#             capital            type
# 0             Kabul  countryCapital
# 1            Tirana  countryCapital
# ...

# %%
#36
res[res['Country Name'] == 'Ukraine']['capital']
# Out:
# 176    Kyiv
# Name: capital, dtype: object

# %%
#37
res1 =  pd.merge(new_df, countrylist, left_on='Country Name', right_on='country',  how='left')
res1.head()
# Out:
#      Country Name Continent Name  Population           GDP  \
# 0     Afghanistan           Asia  41128771.0  1.415197e+10
# 1         Albania         Europe   2775634.0  1.888210e+10
# 2         Algeria         Africa  44903225.0  1.919129e+11
# 3  American Samoa        Oceania     44273.0  6.011000e+08
# 4         Andorra         Europe     79824.0  3.352033e+09
#
#    Education Expenditure (% GDP)  Health Expenditure (% GDP)         country  \
# 0                      13.670101                   10.902580     Afghanistan
# 1                      11.672968                    6.093392         Albania
# 2                      15.354617                    5.035450         Algeria
# 3                            NaN                         NaN  American Samoa
# 4                      10.639908                    6.521148         Andorra
#
#             capital            type
# 0             Kabul  countryCapital
# 1            Tirana  countryCapital
# ...

# %%
#38
res['Health Expenditure (% GDP)'] = res['Health Expenditure (% GDP)'].fillna(0).round().astype(int)
res.head()
# Out:
#      Country Name Continent Name  Population           GDP  \
# 0     Afghanistan           Asia  41128771.0  1.415197e+10
# 1         Albania         Europe   2775634.0  1.888210e+10
# 2         Algeria         Africa  44903225.0  1.919129e+11
# 3  American Samoa        Oceania     44273.0  6.011000e+08
# 4         Andorra         Europe     79824.0  3.352033e+09
#
#    Education Expenditure (% GDP)  Health Expenditure (% GDP)         country  \
# 0                      13.670101                          11     Afghanistan
# 1                      11.672968                           6         Albania
# 2                      15.354617                           5         Algeria
# 3                            NaN                           0  American Samoa
# 4                      10.639908                           7         Andorra
#
#             capital            type
# 0             Kabul  countryCapital
# 1            Tirana  countryCapital
# ...

# %%
import numpy as np

# %%
#39
res['Education Expenditure (% GDP)'] = np.where(res['Education Expenditure (% GDP)'] >= 20, 20,
                                        np.where(res['Education Expenditure (% GDP)'] >= 10, 10, 5))
res.head()
# Out:
#      Country Name Continent Name  Population           GDP  \
# 0     Afghanistan           Asia  41128771.0  1.415197e+10
# 1         Albania         Europe   2775634.0  1.888210e+10
# 2         Algeria         Africa  44903225.0  1.919129e+11
# 3  American Samoa        Oceania     44273.0  6.011000e+08
# 4         Andorra         Europe     79824.0  3.352033e+09
#
#    Education Expenditure (% GDP)  Health Expenditure (% GDP)         country  \
# 0                             10                          11     Afghanistan
# 1                             10                           6         Albania
# 2                             10                           5         Algeria
# 3                              5                           0  American Samoa
# 4                             10                           7         Andorra
#
#             capital            type
# 0             Kabul  countryCapital
# 1            Tirana  countryCapital
# ...
